# %% [markdown]
# <a href="https://colab.research.google.com/github/alfitra/Complete-Python-3-Bootcamp/blob/master/Modul_1_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Animal

# %% [markdown]
# ## a.) Butterfly

# %% [markdown]
# ### sayap

# %%
# membuat kode untuk mengakses file butterfly

# %% [markdown]
# ### antena

# %% [markdown]
# ## b.) Cow

# %%
# membuat kode untuk mengakses file cow

# %% [markdown]
# tempat untuk membuat :
#
# 1. Section
# 2. teks insight
# 3. menyimpan gambar
# 4. dll
#
# `print("hello Wolrd")`
#
# *<b>bisa menggunakan HTML untuk edit teks</b>*
#
# sumber eksplorasi : W3School.com

# %%
l
l
l
l
l
l
l
l

# %% [markdown]
# # Data Operation

# %% [markdown]
# ## data type

# %% [markdown]
# running = ctrl + enter

# %% [markdown]
# Integer, Math Operation :

# %%
a = 10
b = 5
c = a + b
d = a - b
e = a * b
f = a / b

print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# 10
# 5
# 15
# 5
# 50
# 2.0

# %% [markdown]
# String

# %%
str1 = "HaLlo"
str1.lower()
# Out:
# 'hallo'

# %%
str1.upper()
# Out:
# 'HALLO'

# %%
str2 = "yo ya"
print(str2)
str2.replace("yo", "yi")
# Out:
# yo ya
# 'yi ya'

# %% [markdown]
# Boolean

# %%
# Boolean
a = 5
b = 2
c = 1
print(a > b) # True
print(a == b) # False
print((a > b) and (b > c)) # True
print((a < b) and (b > c)) # False
# Out:
# True
# False
# True
# False

# %% [markdown]
# Mengubah Tipe Data

# %%
# mengubah tipe data
# mengubah tipe data dari integer ke string
a = 1
print(a)
a = str(a)

b = 123.01
b = int(b)
print(b)
# Out:
# 1
# 123

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
kata1 = "Saya "
kata2 = "ingin "
kata3 = "makan"
gabungan = kata1  + kata2  + kata3
print(gabungan)
# Out:
# Saya ingin makan

# %%
# saya mau mengatur jumlah angka di belaang koma
a = 16.57142475859
print(round(a, 2))
# Out:
# 16.57

# %% [markdown]
# ### List

# %% [markdown]
# ( a, b, c )
#
# indeks ke-0 = a
# indeks ke-1 = b
# indeks ke-2 = c
#
# berlaku di list, tuple, set

# %%
abjad = ("a", "b", "c")
print(abjad[0])
# Out:
# a

# %%
print(abjad[:2])
# Out:
# ('a', 'b')

# %% [markdown]
# ( a , b , c )
#
# abjad [ dari_0 : dari_1 ]

# %%
print(abjad[1:3])
# Out:
# ('b', 'c')

# %% [markdown]
# Tuple

# %%
abjad = ("a", "b", "c", "d", "e", "f")

# mengambil data dari c sampai e
print(abjad[2:5])

# mengambil data dari c sampai terakhir
print(abjad[2:])
# Out:
# ('c', 'd', 'e')
# ('c', 'd', 'e', 'f')

# %% [markdown]
# List

# %%
abjad=["a","b","c"]
abjad = abjad.remove("b")
print(abjad)
# Out:
# None

# %%
abjad=["a","b","c"]
abjad.remove("b")
print(abjad)

abjad = abjad.remove("c")
print(abjad)
# Out:
# ['a', 'c']
# None

# %%
# metode Append = menambahkan value
abjad = ["a", "b", "c"]
abjad.append("d")
print(abjad)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# Tuple

# %%
# kalau semisal kita punya tuple? apakah bisa di append?
abjad = ("a", "b", "c")
abjad = list(abjad)
abjad.append("d")
print(abjad)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# List

# %%
# menghapus item pada list
abjad = ["a", "b", "c"]
del abjad[1]
print(abjad)
# Out:
# ['a', 'c']

# %%
abjad = ["a", "b", "c"]
abjed = abjad.remove("b")
print(abjad)
# Out:
# ['a', 'c']

# %% [markdown]
# ### Methods

# %%
# mau mengurutkan value di list dari kecil ke besar
abjad = ["c", "b", "d", "a"]
abjad.sort()
print(abjad)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# mau mengurutkan value di list dari besar ke kecil
abjad.sort(reverse=True)
print(abjad)
# Out:
# ['d', 'c', 'b', 'a']

# %%
abjad.sort(reverse=False)
print(abjad)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# Set

# %%
abjad = {"a", "a", "b", "b"}
print("ini adalah set : ", abjad)
abjad = list(abjad)
print("ini adalah list : ", abjad)
abjad.sort()
print(abjad)
# Out:
# ini adalah set :  {'b', 'a'}
# ini adalah list :  ['b', 'a']
# ['a', 'b']

# %%
# saya mau mendapatkan jumlah value dari list
abjad = ["a", "a", "b", "b"]
print(len(abjad))
# Out:
# 4

# %%
# add sama sepert append tapi di set
a = {"a", "b"}
a.add("c")
print(a)
# Out:
# {'b', 'a', 'c'}

# %%
abjad = ["a", "a", "b", "b"]
print(abjad * 2)
# Out:
# ['a', 'a', 'b', 'b', 'a', 'a', 'b', 'b']

# %% [markdown]
# ## Data processing

# %% [markdown]
# Dictionary Data Type

# %%
# membuat sebuah dictionary
data = ({
    "nama": ["John", "jane", "Adi"],
    "umur": [20, 21, 22],
    "hobi" : ["berenang", "senam", "membaca"]
})
print(data)
# Out:
# {'nama': ['John', 'jane', 'Adi'], 'umur': [20, 21, 22], 'hobi': ['berenang', 'senam', 'membaca']}

# %%
import pandas as pd

data = pd.DataFrame({
    "nama": ["John", "jane", "Adi"],
    "umur": [20, 21, 22],
    "hobi" : ["berenang", "senam", "membaca"]
})
print(data)
# Out:
#    nama  umur      hobi
# 0  John    20  berenang
# 1  jane    21     senam
# 2   Adi    22   membaca

# %% [markdown]
# ## Analisis Data CSV

# %% [markdown]
# https://raw.githubusercontent.com/krishna0604/dataset_advanced/refs/heads/main/data_customers_csv.csv

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/krishna0604/dataset_advanced/refs/heads/main/data_customers_csv.csv")

# %%
df.shape
# Out:
# (107, 21)

# %% [markdown]
# Ada 107 baris dan 21 kolom

# %%
df.shape[0]
# Out:
# 107

# %%
df.shape[1]
# Out:
# 21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   registration_id          107 non-null    object
#  1   name                     107 non-null    object
#  2   email                    107 non-null    object
#  3   phone                    104 non-null    float64
#  4   age                      106 non-null    float64
#  5   income_group             107 non-null    int64
#  6   active                   107 non-null    bool
#  7   city                     107 non-null    object
#  8   province                 107 non-null    object
#  9   hobby                    102 non-null    object
#  10  fav_movie                69 non-null     object
#  11  website_visit_count      107 non-null    int64
#  12  website_recency          107 non-null    int64
#  13  website_purchase_rate    107 non-null    float64
# ...

# %%
df.describe()
# Out:
#               phone         age  income_group  website_visit_count  \
# count  1.040000e+02  106.000000    107.000000           107.000000
# mean   6.123076e+09   33.132075      2.803738            51.831776
# std    9.515607e+08   11.480895      1.216547            29.269562
# min    6.284456e+08   15.000000      1.000000             5.000000
# 25%    6.285234e+09   24.250000      2.000000            24.500000
# 50%    6.286627e+09   33.000000      3.000000            49.000000
# 75%    6.287881e+09   43.750000      4.000000            74.000000
# max    6.289633e+09   57.000000      5.000000           100.000000
#
#        website_recency  website_purchase_rate  website_purchase_amount  \
# count       107.000000             107.000000             1.070000e+02
# mean         20.130841               0.675794             8.322712e+05
# std          18.765225               0.243338             1.713776e+06
# min           0.000000               0.000000             0.000000e+00
# ...

# %% [markdown]
# Insight :
#
# 1. kelompok umur ada di rentang 15 - 57 dengan rata rata 33

# %%
df.head(3)
# Out:
#   registration_id                         name  \
# 0      RK20202344  Fakhrul Fandy Widyaningtias
# 1      RK20202345          Ferdiansyah Amalina
# 2      RK20202346            Ficky Rizkyananta
#
#                                    email         phone   age  income_group  \
# 0  fakhrulfandywidyaningtias@outlook.com  6.285244e+09  27.0             2
# 1           ferdiansyahamalina@yahoo.com  6.285245e+09  31.0             3
# 2           fickyrizkyananta@hotmail.com  6.285245e+09  15.0             1
#
#    active                             city        province          hobby  \
# 0   False                    Tanjungpinang  Kepulauan Riau  Amateur radio
# 1    True                            Bogor      Jawa Barat      Animation
# 2    True  Kota Administrasi Jakarta Pusat         Jakarta          Anime
#
#    ... website_visit_count  website_recency  website_purchase_rate  \
# 0  ...                  51               75                   0.68
# ...

# %%
df.head(15)
# Out:
#    registration_id                         name  \
# 0       RK20202344  Fakhrul Fandy Widyaningtias
# 1       RK20202345          Ferdiansyah Amalina
# 2       RK20202346            Ficky Rizkyananta
# 3       RK20202347             Singgih Kharisma
# 4       RK20202348             Jeremiah Dinanti
# 5       RK20202349              Ridhwan Noerani
# 6       RK20202350              Okky Oktaviaman
# 7       RK20202351      Dikposa Yosua Krisnanto
# 8       RK20202351      Dikposa Yosua Krisnanto
# 9       RK20202352                 Dhanu Rahman
# 10      RK20202353                    Bob Arisa
# 11      RK20202354                   Omar Afini
# 12      RK20202355               Sutrisno Rizal
# 13      RK20202356                Hilman Azalia
# 14      RK20202357             Lintang Bertauli
#
#                                     email         phone   age  income_group  \
# 0   fakhrulfandywidyaningtias@outlook.com  6.285244e+09  27.0             2
# ...

# %%
# tail = menampilkan data n terbawah
df.tail(2)
# Out:
#     registration_id            name                      email         phone  \
# 105      RK20202443  Puspita Amalia  puspitaamalia@hotmail.com  6.288690e+09
# 106      RK20202444  Puspita Amalia   puspitaamaliaa@gmail.com  6.281910e+09
#
#       age  income_group  active       city          province          hobby  \
# 105  27.0             2    True  Samarinda  Kalimantan Timur  Ghost hunting
# 106  27.0             2    True  Samarinda  Kalimantan Timur  Ghost hunting
#
#      ... website_visit_count  website_recency  website_purchase_rate  \
# 105  ...                  68               13                   0.68
# 106  ...                  58               10                   0.79
#
#      website_purchase_amount  website_cs_call_count  accept_campaign_1  \
# 105                   340000                      2              False
# 106                   632000                      3              False
#
#      accept_campaign_2  accept_campaign_3  accept_campaign_4  \
# ...

# %%
df.tail(14)
# Out:
#     registration_id                    name                           email  \
# 93       RK20202431          Prima Hermawan    primahermawan@rocketmail.com
# 94       RK20202432             Firman Reza            firmanreza@gmail.com
# 95       RK20202433            Eva Khuadeva         evakhuadeva@rakamin.com
# 96       RK20202434           Bagus Maulana        bagusmaulana@outlook.com
# 97       RK20202435            Citra Citata        citracitata@facebook.com
# 98       RK20202436         Yuni Bukan Sara         yunibukansara@yahoo.com
# 99       RK20202437             Putu Adinda            putuadinda@yahoo.com
# 100      RK20202438            Nurul Latifa           nurullatifa@ymail.com
# 101      RK20202439             Fajar Gusti          fajargusti@hotmail.com
# 102      RK20202440  Amalia Azizah Putriana  amaliaazizahputriana@yahoo.com
# 103      RK20202441          Didin Suherdin         didinsuherdin@yahoo.com
# ...

# %% [markdown]
# Operasi sum, mean, min, max

# %%
# filter data
# pengen ambil hanya kolom phone, age, website_visit_count
df_filter = df[["phone", "age", "website_visit_count"]]
df_filter.head()
# Out:
#             phone   age  website_visit_count
# 35   6.284456e+08  20.0                   73
# 64   6.287814e+09  17.0                   98
# 102  6.283542e+09  57.0                   44
# 67   6.285341e+09  17.0                   47
# 80   6.285256e+09  17.0                   84

# %%
df_filter.sum()
# Out:
# phone                  6.367999e+11
# age                    3.512000e+03
# website_visit_count    5.546000e+03
# dtype: float64

# %%
df_filter.mean()
# Out:
# phone                  6.123076e+09
# age                    3.313208e+01
# website_visit_count    5.183178e+01
# dtype: float64

# %%
df_filter.min()
# Out:
# phone                  628445557.0
# age                           15.0
# website_visit_count            5.0
# dtype: float64

# %%
df_filter.max()
# Out:
# phone                  6.289633e+09
# age                    5.700000e+01
# website_visit_count    1.000000e+02
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   registration_id          107 non-null    object
#  1   name                     107 non-null    object
#  2   email                    107 non-null    object
#  3   phone                    104 non-null    float64
#  4   age                      106 non-null    float64
#  5   income_group             107 non-null    int64
#  6   active                   107 non-null    bool
#  7   city                     107 non-null    object
#  8   province                 107 non-null    object
#  9   hobby                    102 non-null    object
#  10  fav_movie                69 non-null     object
#  11  website_visit_count      107 non-null    int64
#  12  website_recency          107 non-null    int64
#  13  website_purchase_rate    107 non-null    float64
# ...

# %%
df_filter.dtypes
# Out:
# phone                  float64
# age                    float64
# website_visit_count      int64
# dtype: object

# %%
df_filter["age"] = df_filter["age"].astype(str)
# Out:
# <ipython-input-63-c2978d4dccd6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter["age"] = df_filter["age"].astype(str)

# %%
df_filter.dtypes
# Out:
# phone                  float64
# age                     object
# website_visit_count      int64
# dtype: object

# %%
# dari object ke numerik
df_filter["age"] = pd.to_numeric(df_filter["age"], errors="coerce")
# Out:
# <ipython-input-68-393a45138828>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter["age"] = pd.to_numeric(df_filter["age"], errors="coerce")

# %%
df_filter.dtypes
# Out:
# phone                  float64
# age                    float64
# website_visit_count      int64
# dtype: object

# %%
# menggunakan df, bukan df_filter
df["name"].head()
# Out:
# 0    Fakhrul Fandy Widyaningtias
# 1            Ferdiansyah Amalina
# 2              Ficky Rizkyananta
# 3               Singgih Kharisma
# 4               Jeremiah Dinanti
# Name: name, dtype: object

# %%
df["name"] = df["name"].str.lower()
df["name"].head()
# Out:
# 35           alfin chairunisa
# 64              amadea octaza
# 102    amalia azizah putriana
# 67       amalia widi abelardo
# 80               amanda idayu
# Name: name, dtype: object

# %%
df["name"]
# Out:
# 0      Fakhrul Fandy Widyaningtias
# 1              Ferdiansyah Amalina
# 2                Ficky Rizkyananta
# 3                 Singgih Kharisma
# 4                 Jeremiah Dinanti
#                   ...
# 102         Amalia Azizah Putriana
# 103                 Didin Suherdin
# 104              Amelia Sari Putri
# 105                 Puspita Amalia
# 106                 Puspita Amalia
# Name: name, Length: 107, dtype: object

# %%
df["name"] = df["name"].str.upper()
df["name"].head()
# Out:
# 0    FAKHRUL FANDY WIDYANINGTIAS
# 1            FERDIANSYAH AMALINA
# 2              FICKY RIZKYANANTA
# 3               SINGGIH KHARISMA
# 4               JEREMIAH DINANTI
# Name: name, dtype: object

# %% [markdown]
# ### Filtering Column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   registration_id          107 non-null    object
#  1   name                     107 non-null    object
#  2   email                    107 non-null    object
#  3   phone                    104 non-null    float64
#  4   age                      106 non-null    float64
#  5   income_group             107 non-null    int64
#  6   active                   107 non-null    bool
#  7   city                     107 non-null    object
#  8   province                 107 non-null    object
#  9   hobby                    102 non-null    object
#  10  fav_movie                69 non-null     object
#  11  website_visit_count      107 non-null    int64
#  12  website_recency          107 non-null    int64
#  13  website_purchase_rate    107 non-null    float64
# ...

# %%
df["age"]
# Out:
# 0      27.0
# 1      31.0
# 2      15.0
# 3      49.0
# 4      25.0
#        ...
# 102    57.0
# 103    44.0
# 104    32.0
# 105    27.0
# 106    27.0
# Name: age, Length: 107, dtype: float64

# %%
df[["name", "age"]]
# Out:
#                             name   age
# 0    FAKHRUL FANDY WIDYANINGTIAS  27.0
# 1            FERDIANSYAH AMALINA  31.0
# 2              FICKY RIZKYANANTA  15.0
# 3               SINGGIH KHARISMA  49.0
# 4               JEREMIAH DINANTI  25.0
# ..                           ...   ...
# 102       AMALIA AZIZAH PUTRIANA  57.0
# 103               DIDIN SUHERDIN  44.0
# 104            AMELIA SARI PUTRI  32.0
# 105               PUSPITA AMALIA  27.0
# 106               PUSPITA AMALIA  27.0
#
# [107 rows x 2 columns]

# %%
df[df["age"]==20]
# Out:
#    registration_id                       name  \
# 35      RK20202378           ALFIN CHAIRUNISA
# 46      RK20202387  LUKMAN NAUFAL SIMORANGKIR
#
#                                 email         phone   age  income_group  \
# 35          alfinchairunisa@gmail.com  6.284456e+08  20.0             2
# 46  lukmannaufalsimorangkir@gmail.com  6.287890e+09  20.0             2
#
#     active                             city          province     hobby  ...  \
# 35    True                          Bontang  Kalimantan Timur     Music  ...
# 46    True  Kota Administrasi Jakarta Utara           Jakarta  Climbing  ...
#
#    website_visit_count  website_recency  website_purchase_rate  \
# 35                  73                6                   0.83
# 46                  44               16                   0.90
#
#     website_purchase_amount  website_cs_call_count  accept_campaign_1  \
# 35                   332000                      0               True
# ...

# %%
df[df["name"]=="ALFIN CHAIRUNISA"]
# Out:
#    registration_id              name                      email        phone  \
# 35      RK20202378  ALFIN CHAIRUNISA  alfinchairunisa@gmail.com  628445557.0
#
#      age  income_group  active     city          province  hobby  ...  \
# 35  20.0             2    True  Bontang  Kalimantan Timur  Music  ...
#
#    website_visit_count  website_recency  website_purchase_rate  \
# 35                  73                6                   0.83
#
#     website_purchase_amount  website_cs_call_count  accept_campaign_1  \
# 35                   332000                      0               True
#
#     accept_campaign_2  accept_campaign_3  accept_campaign_4  accept_campaign_5
# 35               True               True               True               True
#
# [1 rows x 21 columns]

# %% [markdown]
# Multiple Filtering

# %%
df[(df["age"].isin([20, 21]))]
# Out:
#    registration_id                       name  \
# 35      RK20202378           ALFIN CHAIRUNISA
# 36      RK20202379         REVI ASWIN FATIMAH
# 46      RK20202387  LUKMAN NAUFAL SIMORANGKIR
# 57      RK20202397        ANINDYANTI BAYHACKI
#
#                                 email         phone   age  income_group  \
# 35          alfinchairunisa@gmail.com  6.284456e+08  20.0             2
# 36     reviaswinfatimah@roketmail.com  6.287858e+09  21.0             2
# 46  lukmannaufalsimorangkir@gmail.com  6.287890e+09  20.0             2
# 57       anindyantibayhacki@yahoo.com  6.287860e+09  21.0             2
#
#     active                             city          province       hobby  \
# 35    True                          Bontang  Kalimantan Timur       Music
# 36    True                            Depok        Jawa Barat     Reading
# 46    True  Kota Administrasi Jakarta Utara           Jakarta    Climbing
# ...

# %% [markdown]
# Multi Column

# %%
df[(df["age"]==35) & (df["income_group"] == 3)]
# Out:
#    registration_id             name                         email  \
# 6       RK20202350  OKKY OKTAVIAMAN  okkyoktaviaman@roketmail.com
# 65      RK20202405    AUZY NARENDRA      auzynarendra@outlook.com
# 69      RK20202409      CLARA AMIRA        claraamira@hotmail.com
#
#            phone   age  income_group  active        city            province  \
# 6   6.281906e+09  35.0             3    True   Surakarta         Jawa Tengah
# 65  6.287807e+09  35.0             3    True  Balikpapan    Kalimantan Timur
# 69  6.285328e+09  35.0             3    True  Banjarbaru  Kalimantan Selatan
#
#              hobby  ... website_visit_count  website_recency  \
# 6   Fashion design  ...                   5               19
# 65     Kitesurfing  ...                  22               15
# 69             NaN  ...                  15                0
#
#     website_purchase_rate  website_purchase_amount  website_cs_call_count  \
# ...

# %% [markdown]
# Pattern based filtering

# %%
df[(df["name"].str.contains("AYU"))]
# Out:
#    registration_id            name                      email         phone  \
# 80      RK20202420    AMANDA IDAYU      amandaidayu@yahoo.com  6.285256e+09
# 86      RK20202426  RARAHAYU VEREV  rarahayuverev@outlook.com  6.285216e+09
#
#      age  income_group  active   city     province     hobby  ...  \
# 80  17.0             1    True   Batu   Jawa Timur   Parkour  ...
# 86  15.0             1    True  Tegal  Jawa Tengah  Vacation  ...
#
#    website_visit_count  website_recency  website_purchase_rate  \
# 80                  84               16                   1.00
# 86                  60               25                   0.72
#
#     website_purchase_amount  website_cs_call_count  accept_campaign_1  \
# 80                   600000                      0               True
# 86                   648000                      0               True
#
#     accept_campaign_2  accept_campaign_3  accept_campaign_4  accept_campaign_5
# ...

# %%
df[(df["phone"].astype(str).str.contains("^62878"))]
# Out:
#    registration_id                       name  \
# 25      RK20202368              SAKTI HASANIY
# 26      RK20202369                 RIAN MUFTI
# 27      RK20202370      DONI TEDDO PRASETYANI
# 28      RK20202371                  FAHMI HAQ
# 29      RK20202372             RHEZA NOVIANTI
# 30      RK20202373            HERDARU JUNAIDI
# 32      RK20202375          SEBASTIAN MITSUKO
# 33      RK20202376             RINALDY OCTAZA
# 34      RK20202377            ISMAIL WARDHANI
# 36      RK20202379         REVI ASWIN FATIMAH
# 37      RK20202380           FAISHAL LISTISNI
# 40      RK20202382                IZHAR HALIM
# 41      RK20202383            GARIN SUGIYANTO
# 42      RK20202383            GARIN SUGIYANTO
# 43      RK20202384               EDY FITRIYAH
# 44      RK20202385               GERALDI LALO
# 45      RK20202386           YUSUF TILASNUARI
# 46      RK20202387  LUKMAN NAUFAL SIMORANGKIR
# 47      RK20202388                MARUTO ASIH
# ...

# %%
# dimulai dengan akhiran
df[(df["name"].str.contains("AYU$"))]
# Out:
#    registration_id          name                  email         phone   age  \
# 80      RK20202420  AMANDA IDAYU  amandaidayu@yahoo.com  6.285256e+09  17.0
#
#     income_group  active  city    province    hobby  ... website_visit_count  \
# 80             1    True  Batu  Jawa Timur  Parkour  ...                  84
#
#     website_recency  website_purchase_rate  website_purchase_amount  \
# 80               16                    1.0                   600000
#
#     website_cs_call_count  accept_campaign_1  accept_campaign_2  \
# 80                      0               True              False
#
#     accept_campaign_3  accept_campaign_4  accept_campaign_5
# 80               True              False              False
#
# [1 rows x 21 columns]

# %%
# membuat sebuah dictionary
data = ({
    "nama": ["John", "jane", "Adi"],
    "umur": [20, 21, 22],
    "hobi" : ["berenang", "senam", "membaca"]
})
print(data)
# Out:
# {'nama': ['John', 'jane', 'Adi'], 'umur': [20, 21, 22], 'hobi': ['berenang', 'senam', 'membaca']}

# %%
# menambah kolom ukuran sepatu
data_new = [40, 35, 41]
data["ukuran_sepatu"] = data_new
data
# Out:
# {'nama': ['John', 'jane', 'Adi'],
#  'umur': [20, 21, 22],
#  'hobi': ['berenang', 'senam', 'membaca'],
#  'ukuran_sepatu': [40, 35, 41]}

# %%
data = pd.DataFrame(data)
data
# Out:
#    nama  umur      hobi  ukuran_sepatu
# 0  John    20  berenang             40
# 1  jane    21     senam             35
# 2   Adi    22   membaca             41

# %% [markdown]
# ### Drop Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   registration_id          107 non-null    object
#  1   name                     107 non-null    object
#  2   email                    107 non-null    object
#  3   phone                    104 non-null    float64
#  4   age                      106 non-null    float64
#  5   income_group             107 non-null    int64
#  6   active                   107 non-null    bool
#  7   city                     107 non-null    object
#  8   province                 107 non-null    object
#  9   hobby                    102 non-null    object
#  10  fav_movie                69 non-null     object
#  11  website_visit_count      107 non-null    int64
#  12  website_recency          107 non-null    int64
#  13  website_purchase_rate    107 non-null    float64
# ...

# %% [markdown]
# Drop Column

# %%
df = df.drop("name", axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   registration_id          107 non-null    object
#  1   email                    107 non-null    object
#  2   phone                    104 non-null    float64
#  3   age                      106 non-null    float64
#  4   income_group             107 non-null    int64
#  5   active                   107 non-null    bool
#  6   city                     107 non-null    object
#  7   province                 107 non-null    object
#  8   hobby                    102 non-null    object
#  9   fav_movie                69 non-null     object
#  10  website_visit_count      107 non-null    int64
#  11  website_recency          107 non-null    int64
#  12  website_purchase_rate    107 non-null    float64
#  13  website_purchase_amount  107 non-null    int64
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/krishna0604/dataset_advanced/refs/heads/main/data_customers_csv.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   registration_id          107 non-null    object
#  1   name                     107 non-null    object
#  2   email                    107 non-null    object
#  3   phone                    104 non-null    float64
#  4   age                      106 non-null    float64
#  5   income_group             107 non-null    int64
#  6   active                   107 non-null    bool
#  7   city                     107 non-null    object
#  8   province                 107 non-null    object
#  9   hobby                    102 non-null    object
#  10  fav_movie                69 non-null     object
#  11  website_visit_count      107 non-null    int64
#  12  website_recency          107 non-null    int64
#  13  website_purchase_rate    107 non-null    float64
# ...

# %% [markdown]
# ### Duplicated Columns

# %%
df[df["name"]=="Dikposa Yosua Krisnanto"]
# Out:
#   registration_id                     name                              email  \
# 7      RK20202351  Dikposa Yosua Krisnanto  dikposayosuakrisnanto@hotmail.com
# 8      RK20202351  Dikposa Yosua Krisnanto  dikposayosuakrisnanto@hotmail.com
#
#           phone   age  income_group  active                             city  \
# 7  6.281907e+09  28.0             2   False  Kota Administrasi Jakarta Pusat
# 8  6.281907e+09  28.0             2   False  Kota Administrasi Jakarta Pusat
#
#   province           hobby  ... website_visit_count  website_recency  \
# 7  Jakarta  Fingerpainting  ...                  70               57
# 8  Jakarta  Fingerpainting  ...                  70               57
#
#    website_purchase_rate  website_purchase_amount  website_cs_call_count  \
# 7                    0.0                        0                      0
# 8                    0.0                        0                      0
#
# ...

# %%
df[df.duplicated(keep = False) == True]
# Out:
#    registration_id                     name  \
# 7       RK20202351  Dikposa Yosua Krisnanto
# 8       RK20202351  Dikposa Yosua Krisnanto
# 38      RK20202381              Jova Imania
# 39      RK20202381              Jova Imania
# 41      RK20202383          Garin Sugiyanto
# 42      RK20202383          Garin Sugiyanto
# 51      RK20202392             Sigit Amalia
# 52      RK20202392             Sigit Amalia
# 91      RK20202431           Prima Hermawan
# 92      RK20202431           Prima Hermawan
# 93      RK20202431           Prima Hermawan
#
#                                 email         phone   age  income_group  \
# 7   dikposayosuakrisnanto@hotmail.com  6.281907e+09  28.0             2
# 8   dikposayosuakrisnanto@hotmail.com  6.281907e+09  28.0             2
# 38               jovaimania@gmail.com  6.284688e+08  17.0             1
# 39               jovaimania@gmail.com  6.284688e+08  17.0             1
# ...

# %%
df[df.duplicated(keep = "first") == True]
# Out:
#    registration_id                     name  \
# 8       RK20202351  Dikposa Yosua Krisnanto
# 39      RK20202381              Jova Imania
# 42      RK20202383          Garin Sugiyanto
# 52      RK20202392             Sigit Amalia
# 92      RK20202431           Prima Hermawan
# 93      RK20202431           Prima Hermawan
#
#                                 email         phone   age  income_group  \
# 8   dikposayosuakrisnanto@hotmail.com  6.281907e+09  28.0             2
# 39               jovaimania@gmail.com  6.284688e+08  17.0             1
# 42           garinsugiyanto@yahoo.com  6.287881e+09  33.0             3
# 52          sigitamalia@roketmail.com  6.287893e+09  48.0             4
# 92       primahermawan@rocketmail.com  6.281856e+09  50.0             5
# 93       primahermawan@rocketmail.com  6.281856e+09  50.0             5
#
#     active                             city          province           hobby  \
# ...

# %%
df[df.duplicated(keep = True) == True]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-35b01405dc68> in <cell line: 0>()
# ----> 1 df[df.duplicated(keep = True) == True]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6959
#    6960             ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
# -> 6961             result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#    6962         return result.__finalize__(self, method="duplicated")
#    6963
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.__pyx_fuse_3duplicated()
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.duplicated()
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.duplicated_int64()
#
# ValueError: keep must be either "first", "last" or False

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# ### Mengurutkan Data Frame

# %%
df.head()
# Out:
#   registration_id                         name  \
# 0      RK20202344  Fakhrul Fandy Widyaningtias
# 1      RK20202345          Ferdiansyah Amalina
# 2      RK20202346            Ficky Rizkyananta
# 3      RK20202347             Singgih Kharisma
# 4      RK20202348             Jeremiah Dinanti
#
#                                    email         phone   age  income_group  \
# 0  fakhrulfandywidyaningtias@outlook.com  6.285244e+09  27.0             2
# 1           ferdiansyahamalina@yahoo.com  6.285245e+09  31.0             3
# 2           fickyrizkyananta@hotmail.com  6.285245e+09  15.0             1
# 3            singgihkharisma@hotmail.com  6.285245e+09  49.0             4
# 4                    jeremia@rakamin.com  6.285245e+09  25.0             2
#
#    active                             city        province          hobby  \
# 0   False                    Tanjungpinang  Kepulauan Riau  Amateur radio
# 1    True                            Bogor      Jawa Barat      Animation
# ...

# %%
df.sort_values(by = "age")
# Out:
#     registration_id                    name                           email  \
# 2        RK20202346       Ficky Rizkyananta    fickyrizkyananta@hotmail.com
# 70       RK20202410             Hilary Adha            hilaryadha@yahoo.com
# 86       RK20202426          Rarahayu Verev       rarahayuverev@outlook.com
# 81       RK20202421      Ovienov Asti Idrus    ovienovastiidrus@outlook.com
# 60       RK20202400           Rianita Santi          rianitasanti@yahoo.com
# ..              ...                     ...                             ...
# 92       RK20202431          Prima Hermawan    primahermawan@rocketmail.com
# 96       RK20202434           Bagus Maulana        bagusmaulana@outlook.com
# 101      RK20202439             Fajar Gusti          fajargusti@hotmail.com
# 102      RK20202440  Amalia Azizah Putriana  amaliaazizahputriana@yahoo.com
# 31       RK20202374            Eka Tiodimar                ekatio@yahoo.com
#
#             phone   age  income_group  active  \
# ...

# %% [markdown]
# Dari besar ke kecil

# %%
df.sort_values(by = "age", ascending = False)
# Out:
#     registration_id                    name                           email  \
# 102      RK20202440  Amalia Azizah Putriana  amaliaazizahputriana@yahoo.com
# 101      RK20202439             Fajar Gusti          fajargusti@hotmail.com
# 96       RK20202434           Bagus Maulana        bagusmaulana@outlook.com
# 91       RK20202431          Prima Hermawan    primahermawan@rocketmail.com
# 30       RK20202373         Herdaru Junaidi      herdarujunaidi@outlook.com
# ..              ...                     ...                             ...
# 60       RK20202400           Rianita Santi          rianitasanti@yahoo.com
# 81       RK20202421      Ovienov Asti Idrus    ovienovastiidrus@outlook.com
# 2        RK20202346       Ficky Rizkyananta    fickyrizkyananta@hotmail.com
# 70       RK20202410             Hilary Adha            hilaryadha@yahoo.com
# 31       RK20202374            Eka Tiodimar                ekatio@yahoo.com
#
#             phone   age  income_group  active  \
# ...

# %%
df.sort_values(["name", "age"], inplace = True, ascending = True)

# %% [markdown]
# ### Checking Null Values

# %%
df[df["age"].isnull()]
# Out:
#    registration_id          name             email  phone  age  income_group  \
# 31      RK20202374  Eka Tiodimar  ekatio@yahoo.com    NaN  NaN             5
#
#     active                             city province  hobby  ...  \
# 31    True  Kota Administrasi Jakarta Utara  Jakarta  Magic  ...
#
#    website_visit_count  website_recency  website_purchase_rate  \
# 31                  85               27                    0.0
#
#     website_purchase_amount  website_cs_call_count  accept_campaign_1  \
# 31                        0                      0               True
#
#     accept_campaign_2  accept_campaign_3  accept_campaign_4  accept_campaign_5
# 31               True               True               True               True
#
# [1 rows x 21 columns]

# %%
df[df["age"].notnull()]
# Out:
#     registration_id                         name  \
# 0        RK20202344  Fakhrul Fandy Widyaningtias
# 1        RK20202345          Ferdiansyah Amalina
# 2        RK20202346            Ficky Rizkyananta
# 3        RK20202347             Singgih Kharisma
# 4        RK20202348             Jeremiah Dinanti
# ..              ...                          ...
# 102      RK20202440       Amalia Azizah Putriana
# 103      RK20202441               Didin Suherdin
# 104      RK20202442            Amelia Sari Putri
# 105      RK20202443               Puspita Amalia
# 106      RK20202444               Puspita Amalia
#
#                                      email         phone   age  income_group  \
# 0    fakhrulfandywidyaningtias@outlook.com  6.285244e+09  27.0             2
# 1             ferdiansyahamalina@yahoo.com  6.285245e+09  31.0             3
# 2             fickyrizkyananta@hotmail.com  6.285245e+09  15.0             1
# ...

# %% [markdown]
# # Export DataFrame

# %%
df.head()
# Out:
#     registration_id                    name                           email  \
# 35       RK20202378        Alfin Chairunisa       alfinchairunisa@gmail.com
# 64       RK20202404           Amadea Octaza      amadeaoctaza@roketmail.com
# 102      RK20202440  Amalia Azizah Putriana  amaliaazizahputriana@yahoo.com
# 67       RK20202407    Amalia Widi Abelardo  amaliawidiabelardo@outlook.com
# 80       RK20202420            Amanda Idayu           amandaidayu@yahoo.com
#
#             phone   age  income_group  active  \
# 35   6.284456e+08  20.0             2    True
# 64   6.287814e+09  17.0             1    True
# 102  6.283542e+09  57.0             5    True
# 67   6.285341e+09  17.0             1    True
# 80   6.285256e+09  17.0             1    True
#
#                                   city          province        hobby  ...  \
# 35                             Bontang  Kalimantan Timur        Music  ...
# 64                             Cirebon        Jawa Barat      Hunting  ...
# ...

# %%
df.to_csv("data_filter_nama.csv", index = False)

# %%
df_nama = df["name"]

# %%
df_nama.head()
# Out:
# 0    Fakhrul Fandy Widyaningtias
# 1            Ferdiansyah Amalina
# 2              Ficky Rizkyananta
# 3               Singgih Kharisma
# 4               Jeremiah Dinanti
# Name: name, dtype: object

# %%
new_data = pd.DataFrame(["Agung", "Krishna", "Dwipayana"])

df_nama = pd.concat([df_nama, new_data], ignore_index=True)

# %%
df_nama.head()
# Out:
#                              0 name
# 0  Fakhrul Fandy Widyaningtias  NaN
# 1          Ferdiansyah Amalina  NaN
# 2            Ficky Rizkyananta  NaN
# 3             Singgih Kharisma  NaN
# 4             Jeremiah Dinanti  NaN

# %%
df_nama[df_nama["name"]=="Agung"]
# Out:
#        0   name
# 107  NaN  Agung

# %% [markdown]
# SQL -> merge data lama dan data baru ( inner jon )
